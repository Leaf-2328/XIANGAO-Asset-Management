# %%
import pandas as pd 
import all_index_vis
import os
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
import datetime

os.environ['NLS_LANG'] = 'SIMPLIFIED CHINESE_CHINA.UTF8'

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Microsoft YaHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
import matplotlib
merged_all_df = pd.read_pickle('index_monitor.pkl')

today_time = date.today()
past_time = (today_time - datetime.timedelta(days=50)).strftime('%Y%m%d')
year_ago_time = (today_time - datetime.timedelta(days=365)).strftime('%Y%m%d')

# %% [markdown]
# ## 中证500日收益、沪深300日收益、全市场中位日收益、成交额关系图

# %%
all_index_vis.get_zz500_hs300_all_market_compare(merged_all_df)

# %% [markdown]
# ## 集合竞价委托笔数走势图

# %%
all_index_vis.get_open_auction_number(merged_all_df)

# %% [markdown]
# ## 上涨、下跌股票数量关系图

# %%
target_df = merged_all_df[merged_all_df['date'].astype(float)>int(past_time)]
all_index_vis.get_number_ratio_up_all_stocks(target_df)

# %% [markdown]
# ## 涨停、跌停股票数量关系图

# %%
up_down_df = merged_all_df[merged_all_df['date'].astype(float)>int(past_time)]
all_index_vis.get_number_limit_up_down(up_down_df)

# %% [markdown]
# ## 茅40、抱团50股收益图及其成交额关系图

# %%
info_df = merged_all_df[merged_all_df['date'].astype(float)>int(year_ago_time)]
all_index_vis.get_baotuan50_mao40_ret_plot(info_df)

# %% [markdown]
# ## 大盘风格指数图

# %%
all_index_vis.get_market_indexs_plot(450)

# %% [markdown]
# ## 行业成交量乖离分析

# %%
all_index_vis.get_amount_bias_heatmap()
